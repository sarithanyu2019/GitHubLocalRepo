# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# url1 = 'https://raw.githubusercontent.com/fivethirtyeight/data/master/'
# • url2 = 'college-majors/recent-grads.csv'
df = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/college-majors/recent-grads.csv')

# %%
df
# Out:
#      Rank  Major_code                                          Major  \
# 0       1        2419                          PETROLEUM ENGINEERING
# 1       2        2416                 MINING AND MINERAL ENGINEERING
# 2       3        2415                      METALLURGICAL ENGINEERING
# 3       4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4       5        2405                           CHEMICAL ENGINEERING
# 5       6        2418                            NUCLEAR ENGINEERING
# 6       7        6202                              ACTUARIAL SCIENCE
# 7       8        5001                     ASTRONOMY AND ASTROPHYSICS
# 8       9        2414                         MECHANICAL ENGINEERING
# 9      10        2408                         ELECTRICAL ENGINEERING
# 10     11        2407                           COMPUTER ENGINEERING
# 11     12        2401                          AEROSPACE ENGINEERING
# 12     13        2404                         BIOMEDICAL ENGINEERING
# ...

# %%
df['Major'].nunique()
# Out:
# 173

# %%
len(df)
# Out:
# 173

# %%
df['Major'].nunique()==len(df)
# Out:
# True

# %%
# df['Median']
# df.set_index('Major').sort_values('Median',ascending=False)['Median'].iloc[:10]
df.set_index('Major').sort_values('Median',ascending=False).iloc[:10,:]['Median'].plot.barh()

# %%
df = pd.read_csv('http://pages.stern.nyu.edu/~dbackus/Data/debt.csv')

# %%
df
# Out:
#      ARG   DEU    GRC  Year
# 0  137.5  59.2   98.1  2002
# 1  106.0  64.6   94.9  2004
# 2   61.8  66.3  102.9  2006
# 3   47.0  64.9  108.8  2008
# 4   39.1  80.3  145.7  2010
# 5   37.3  79.0  156.5  2012
# 6   48.6  73.1  177.2  2014

# %%
df.set_index('Year').plot()

# %%
fig,ax = plt.subplots()
df.set_index('Year').plot(ax=ax,color=['r','b','g'])

# %%
df = df.set_index('Year')

# %%
df.columns
# Out:
# Index(['ARG', 'DEU', 'GRC'], dtype='object')

# %%
y1 = df['ARG']
y2 = df['DEU']
y3 = df['GRC']
x = df.index
fig,ax= plt.subplots()
ax.plot(x,y1,linewidth=2)
ax.plot(x,y2,linewidth=1)
ax.plot(x,y3,linewidth=1)
ax.set_title('Debt')
leg = plt.legend()

# %%
fig,ax = plt.subplots()
df.plot(ax=ax)
ax.get_children()[0].set_linewidth(7)
# ax.legend()

# %%
fig,ax = plt.subplots()
for i in df.columns:
    if i=='ARG':
        df[i].plot(ax=ax,linewidth=7)
    else:
        df[i].plot(ax=ax)
ax.legend(df.columns)

# %%
fig,ax = plt.subplots()
df.plot(ax=ax,color=['r','b','g'])
df['ARG'].plot(ax=ax,linewidth=7,color='r')

# %%
df.plot()

# %%
fig,somethingelse = plt.subplots()
df.plot(ax=somethingelse)
somethingelse.set_title('Hello')
# Out:
# Text(0.5,1,'Hello')

# %%
data = {'BRA': [13.37, 13.30, 14.34, 15.07, 15.46, 15.98, 16.10],
'JPN': [33.43, 31.83, 33.71, 34.29, 35.60, 36.79, 37.39],
'USA': [48.30, 46.91, 48.31, 49.72, 51.41, 52.94, 54.60],
'Year': [2008, 2009, 2010, 2011, 2012, 2013, 2014]}
weo = pd.DataFrame(data)

# %%
# weo.dtypes

# %%
weo = weo.set_index('Year')

# %%
weo
# Out:
#         BRA    JPN    USA
# Year
# 2008  13.37  33.43  48.30
# 2009  13.30  31.83  46.91
# 2010  14.34  33.71  48.31
# 2011  15.07  34.29  49.72
# 2012  15.46  35.60  51.41
# 2013  15.98  36.79  52.94
# 2014  16.10  37.39  54.60

# %%
fig,ax = plt.subplots()
weo.plot.bar(stacked=True,color=['r','y','b'],ax=ax)
ax.set_facecolor('black')
ax.set_title('GDP',size=20,fontweight='bold')
ax.legend(loc='center left',bbox_to_anchor=(1,0.5))

x = [-.2,.8,1.8,2.8,3.8,4.8,5.8]
y = [5,30,70]
for i in x:
    for j in y:
        ax.text(i,j,str(weo.iloc[x.index(i),y.index(j)]),size=10)
ax.text(10,50,'xyz')
# Out:
# Text(10,50,'xyz')

# %%
data = {'Size': ['1 to 4', '5 to 9', '10 to 19', '20 to 49', '50 to 99', '100 to 249', '250 to 499', '500 to 999',
'1000 to 2499', '2500 to 4999', '5000 to 9999', '10000+'],
'Firms': [2846416, 1020772, 598153, 373345, 115544, 63845, 19389, 9588, 6088, 2287, 1250, 1357],
'Emp': [5998912, 6714924, 8151891, 11425545, 8055535, 9788341, 6611734, 6340775, 8321486,
6738218, 6559020, 32556671]}
bds = pd.DataFrame(data)
bds = bds.set_index('Size')

# %%
bds
# Out:
#                 Firms       Emp
# Size
# 1 to 4        2846416   5998912
# 5 to 9        1020772   6714924
# 10 to 19       598153   8151891
# 20 to 49       373345  11425545
# 50 to 99       115544   8055535
# 100 to 249      63845   9788341
# 250 to 499      19389   6611734
# 500 to 999       9588   6340775
# 1000 to 2499     6088   8321486
# 2500 to 4999     2287   6738218
# 5000 to 9999     1250   6559020
# 10000+           1357  32556671

# %%
# np.log(bds['Firms']).plot.barh(figsize=(10,10))
bds['Firms'].plot.barh(figsize=(10,10))

# %%
ghr = pd.read_csv('master_data_ready.csv')

# %%
ghr = ghr.replace('\\N',np.nan)

# %%
ghr
# Out:
#                                   job_id                vertical  \
# 0       20198581751789701529910950958638  Information Technology
# 1        8895868916034283132954081837418  Information Technology
# 2        1519847330480116680516242585467  Information Technology
# 3       92511853348028679647877877985294  Information Technology
# 4         490138684948094100363899533762  Information Technology
# 5       74657902746882254946742123272434  Information Technology
# 6       67959912699822604603156520211049  Information Technology
# 7       62960553541696238196645947323426  Information Technology
# 8       90717759116185198593932094841046  Information Technology
# 9       16387272974132263790431897281915  Information Technology
# 10      72696625716373834009704285573063  Information Technology
# 11       7574193811517788303631671726249  Information Technology
# 12       9522301324327623359690770686252  Information Technology
# ...

# %%
ghr['company'].value_counts()
# Out:
# Wells Fargo                                           782
# Leidos                                                634
# General Dynamics Information Technology               603
# SAIC                                                  448
# Microsoft                                             397
# JP Morgan Chase                                       394
# BAE Systems                                           392
# Booz Allen Hamilton                                   326
# Allied Universal                                      316
# PNC Financial Services Group                          310
# TEKSystems                                            291
# Deloitte                                              264
# Accenture                                             244
# Lockheed Martin                                       230
# Banner Health                                         226
# Cognizant                                             215
# ...

# %%
ghr.loc[ghr['company']=='Wells Fargo','salary'].mean()
# Out:
# 99550.0

# %%
ghr.loc[ghr['company']=='Leidos','salary'].mean()
# Out:
# 85776.28233438486

# %%
top_companies = ghr['company'].value_counts().iloc[:10].index

# %%
top_companies
# Out:
# Index(['Wells Fargo', 'Leidos', 'General Dynamics Information Technology',
#        'SAIC', 'Microsoft', 'JP Morgan Chase', 'BAE Systems',
#        'Booz Allen Hamilton', 'Allied Universal',
#        'PNC Financial Services Group'],
#       dtype='object')

# %%
ghr.loc[ghr['company'].isin(top_companies),:]
# Out:
#                                   job_id                vertical  \
# 53       7955450235772249401977199367187  Information Technology
# 61      45230337933216733091735774621770  Information Technology
# 196     97867142837488402514277774467367  Information Technology
# 254     19330552160381602219914962881265  Information Technology
# 276     71299246174044327312442213408820  Information Technology
# 280     53090848651755366660513737499079  Information Technology
# 293      6148237398440176775376543448300  Information Technology
# 363       467895701373045028283543226368  Information Technology
# 413     51378815431178086145259877909568  Information Technology
# 430     18396944660472507504542277085363  Information Technology
# 449      5844413315714480324000269056574  Information Technology
# 454      6987831963477359775183948327121  Information Technology
# 458     74868479210042348041573939065997  Information Technology
# ...

# %%
ghr.groupby('company')['salary'].mean()
# Out:
# company
# #twiceasnice Recruiting                     77651.000000
# &pizza                                      24733.000000
# 'ike Group                                 101959.000000
# .Honduras, Soto Cano Airbase                84133.000000
# 014 - Cincinnati Division                   19411.000000
# 060 - General Office                        35702.000000
# 1 Source Consulting                         60543.500000
# 1 Stop HR                                   48808.000000
# 1 point sys LLC                             73463.000000
# 1-800 Accountant                            22177.000000
# 1-800-GOT-JUNK?                             29682.000000
# 1-800-GOT-JUNK? St Louis                    31698.000000
# 1-800-Got-Junk | RSM Junk 1, LLC            23512.000000
# 1-800-HANSONS                               45722.500000
# 1010data                                    90735.000000
# 10x Genomics                               101938.500000
# ...

# %%
ghr.loc[ghr['company'].isin(top_companies),:].groupby('company')['salary'].mean()
# Out:
# company
# Allied Universal                            28991.389241
# BAE Systems                                 83561.311224
# Booz Allen Hamilton                        106233.030675
# General Dynamics Information Technology     78984.394693
# JP Morgan Chase                             92243.502538
# Leidos                                      85776.282334
# Microsoft                                  108562.491184
# PNC Financial Services Group                65240.080645
# SAIC                                        93498.392857
# Wells Fargo                                 99550.000000
# Name: salary, dtype: float64

# %%
top_cities = ghr['city'].value_counts().iloc[:10].index

# %%
top_df = ghr.loc[(ghr['company'].isin(top_companies))&
                (ghr['city'].isin(top_cities)),:]

# %%
top_df
# Out:
#                                   job_id                vertical  \
# 53       7955450235772249401977199367187  Information Technology
# 363       467895701373045028283543226368  Information Technology
# 1561    48020264441568927672366851147667  Information Technology
# 1986    94862041347132808898027840761556  Information Technology
# 2025     3182655817507572920581877768223  Information Technology
# 2077    13276952798398615936845357322683  Information Technology
# 2312     3456921621334620296545450823412  Information Technology
# 2629    76829986731346773518343156513125  Information Technology
# 2697    74133591169804936250169761567008  Information Technology
# 2940    15803666436640027090901623553076  Information Technology
# 3093    69631505344232906322193912839827  Information Technology
# 3194     3075061850612133305421650087444  Information Technology
# 3283    96888502147068038286851470222163  Information Technology
# ...

# %%
top_df.dtypes
# Out:
# job_id          object
# vertical        object
# company         object
# post_date       object
# fill_date       object
# time_to_fill    object
# salary           int64
# location        object
# city            object
# state           object
# zip             object
# county          object
# region_state    object
# latitude        object
# longitude       object
# dtype: object

# %%
# top_df.groupby('company',as_index=False)['salary'].mean()
# top_df.groupby('company')[['salary']].mean()
# top_df.groupby(['company','city'])[['salary']].mean()
top_df.groupby(['company','city'],as_index=False)[['salary']].mean()
# Out:
#                                     company           city         salary
# 0                          Allied Universal        Atlanta   25085.666667
# 1                          Allied Universal         Austin   26731.500000
# 2                          Allied Universal         Boston   28382.000000
# 3                          Allied Universal        Chicago   26770.000000
# 4                          Allied Universal         Dallas   27227.333333
# 5                          Allied Universal        Houston   29267.625000
# 6                          Allied Universal  New York City   37731.000000
# 7                          Allied Universal  San Francisco   34364.000000
# 8                               BAE Systems         Austin   82280.125000
# 9                               BAE Systems      Charlotte   73577.200000
# 10                              BAE Systems         Dallas   95767.333333
# 11                              BAE Systems     Washington   89607.125000
# ...

# %%
top_df['time_to_fill'] = pd.to_numeric(top_df['time_to_fill'])
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
top_df['count'] =1
top_df
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                                   job_id                vertical  \
# 53       7955450235772249401977199367187  Information Technology
# 363       467895701373045028283543226368  Information Technology
# 1561    48020264441568927672366851147667  Information Technology
# 1986    94862041347132808898027840761556  Information Technology
# 2025     3182655817507572920581877768223  Information Technology
# 2077    13276952798398615936845357322683  Information Technology
# 2312     3456921621334620296545450823412  Information Technology
# 2629    76829986731346773518343156513125  Information Technology
# ...

# %%
top_df.groupby(['company','city'],as_index=False)['salary','time_to_fill'].mean()
# top_df.groupby(['company','city'],as_index=False)['count'].sum()
# Out:
#                                     company           city         salary  \
# 0                          Allied Universal        Atlanta   25085.666667
# 1                          Allied Universal         Austin   26731.500000
# 2                          Allied Universal         Boston   28382.000000
# 3                          Allied Universal        Chicago   26770.000000
# 4                          Allied Universal         Dallas   27227.333333
# 5                          Allied Universal        Houston   29267.625000
# 6                          Allied Universal  New York City   37731.000000
# 7                          Allied Universal  San Francisco   34364.000000
# 8                               BAE Systems         Austin   82280.125000
# 9                               BAE Systems      Charlotte   73577.200000
# 10                              BAE Systems         Dallas   95767.333333
# 11                              BAE Systems     Washington   89607.125000
# ...

# %%
top_df['time_to_fill']
# Out:
# 53          NaN
# 363         NaN
# 1561        NaN
# 1986        NaN
# 2025        NaN
# 2077        NaN
# 2312       36.0
# 2629        NaN
# 2697        NaN
# 2940       13.0
# 3093        NaN
# 3194        NaN
# 3283       21.0
# 3567        NaN
# 3623        9.0
# 4013        NaN
# 4029        NaN
# 4549        NaN
# 4672        NaN
# 4805        NaN
# 5268        NaN
# 5375        NaN
# 5378        NaN
# 5443        NaN
# 5733        NaN
# 6308        NaN
# 6411        NaN
# 7772        NaN
# 7914        NaN
# 8315       77.0
#           ...
# 190580      NaN
# 191038      NaN
# 191146      NaN
# 191485      5.0
# 191537      NaN
# 192242      NaN
# 192341      NaN
# 192793      NaN
# 193694     85.0
# 194240      NaN
# 194401      NaN
# 194486      NaN
# 194521    120.0
# 195257     95.0
# 195290      NaN
# 195498      NaN
# 195707      NaN
# 195708     14.0
# 196368      NaN
# 196628      NaN
# 196634      NaN
# 198489      NaN
# 198801      NaN
# 198821      NaN
# ...

# %%
agg_df = top_df.groupby('company',as_index=False).agg({'salary':np.mean,'time_to_fill':np.median,'count':sum})

# %%
(agg_df['salary']*agg_df['count']).sum()/agg_df['count'].sum()
# Out:
# 97395.87654320987

# %%
agg_df['salary'].mean()
# Out:
# 88165.50896519843

# %%
top_df['company'].nunique()
# Out:
# 10

# %%
top_df.groupby(['company','city'],as_index=False)['salary'].mean()
# Out:
#                                     company           city         salary
# 0                          Allied Universal        Atlanta   25085.666667
# 1                          Allied Universal         Austin   26731.500000
# 2                          Allied Universal         Boston   28382.000000
# 3                          Allied Universal        Chicago   26770.000000
# 4                          Allied Universal         Dallas   27227.333333
# 5                          Allied Universal        Houston   29267.625000
# 6                          Allied Universal  New York City   37731.000000
# 7                          Allied Universal  San Francisco   34364.000000
# 8                               BAE Systems         Austin   82280.125000
# 9                               BAE Systems      Charlotte   73577.200000
# 10                              BAE Systems         Dallas   95767.333333
# 11                              BAE Systems     Washington   89607.125000
# ...

# %%
top_df.pivot_table(index='company',columns='city',values='salary',aggfunc='mean').to_excel('pivot_example.xlsx')

# %%
top_df.pivot_table(index='company',columns='city',values='salary',aggfunc='mean').to_html('html_example.html')

# %%
# top_df.groupby('city')['salary'].mean().sort_values().plot.bar()
top_df.groupby('company')['salary'].mean().sort_values().plot.bar()

# %%
ghr['company'] = ghr['company'].fillna('empty')

# %%
ghr['comp_ct'] = ghr.groupby('company')['job_id'].transform(len)

# %%
ghr.loc[(ghr['comp_ct']>500)&(ghr['comp_ct']<100000),:]
# Out:
#                                   job_id                vertical  \
# 53       7955450235772249401977199367187  Information Technology
# 196     97867142837488402514277774467367  Information Technology
# 254     19330552160381602219914962881265  Information Technology
# 280     53090848651755366660513737499079  Information Technology
# 363       467895701373045028283543226368  Information Technology
# 413     51378815431178086145259877909568  Information Technology
# 454      6987831963477359775183948327121  Information Technology
# 458     74868479210042348041573939065997  Information Technology
# 547     89387346357079061037749644763764  Information Technology
# 726      3398977242085500845818416034422  Information Technology
# 1037     6146329831616909736946637362264  Information Technology
# 1108    80953819528519092139809248434735  Information Technology
# 1222     8084410573761236262738641008566  Information Technology
# ...
