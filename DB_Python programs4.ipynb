# %%
def pocket_change(p,n,d,q):
    dol = p*.01 + n*.05 + d*.1 + q*.25
    return '$'+str(round(dol,2))

# %%
pocket_change(1,2,3,4)
# Out:
# '$1.41'

# %%
first = 'Wilhelmina'
last = 'Grubbly-Plank'

# %%
last.split('-')
# Out:
# ['Grubbly', 'Plank']

# %%
combo = first + ' ' + last[0] + '.'
combo
# Out:
# 'Wilhelmina G.'

# %%
def combo(f,l):
    return f + ' ' + l[0] + '.'

# %%
combo('Ben','Zweig')
# Out:
# 'Ben Z.'

# %%
multiples_3 = [n for n in range(0,31) if n%3==0]
sum(multiples_3)
# Out:
# 165

# %%
total = 0
for i in range(0,31):
    if i/3 == int(i/3):
        total = total+i

# %%
total
# Out:
# 165

# %%
paren = ['When we went to town on Monday (it was so early!) everyone was falling asleep', 
         'It is obvious (so obvious) that I am going to get a good grade on this exam',
         'As she sang her famous line (the one they wrote that article about) the crowd went wild']

# %%
paren
# Out:
# ['When we went to town on Monday (it was so early!) everyone was falling asleep',
#  'It is obvious (so obvious) that I am going to get a good grade on this exam',
#  'As she sang her famous line (the one they wrote that article about) the crowd went wild']

# %%
paren[0]
# Out:
# 'When we went to town on Monday (it was so early!) everyone was falling asleep'

# %%
paren[0].replace('(','- ').replace(')',' -')
# Out:
# 'When we went to town on Monday - it was so early! - everyone was falling asleep'

# %%
for s in paren:
    print(s.replace('(','- ').replace(')',' -'))
# Out:
# When we went to town on Monday - it was so early! - everyone was falling asleep
# It is obvious - so obvious - that I am going to get a good grade on this exam
# As she sang her famous line - the one they wrote that article about - the crowd went wild

# %%
[j.replace('(','- ').replace(')',' -') for j in paren]
# Out:
# ['When we went to town on Monday - it was so early! - everyone was falling asleep',
#  'It is obvious - so obvious - that I am going to get a good grade on this exam',
#  'As she sang her famous line - the one they wrote that article about - the crowd went wild']

# %%
paren
# Out:
# ['When we went to town on Monday (it was so early!) everyone was falling asleep',
#  'It is obvious (so obvious) that I am going to get a good grade on this exam',
#  'As she sang her famous line (the one they wrote that article about) the crowd went wild']

# %%
paren[0][:31]
# Out:
# 'When we went to town on Monday '

# %%
for i in paren:
    print(i.find('('),i.find(')'))
# Out:
# 31 48
# 14 25
# 28 66

# %%
paren[0][:31]+paren[0][50:]
# Out:
# 'When we went to town on Monday everyone was falling asleep'

# %%
paren[0][:paren[0].find('(')]+paren[0][paren[0].find(')')+2:]
# Out:
# 'When we went to town on Monday everyone was falling asleep'

# %%
def remove_paren(s):
    return s[:s.find('(')]+s[s.find(')')+2:]

# %%
new_list = []
for i in paren:
    new_list.append(remove_paren(i))
new_list
# Out:
# ['When we went to town on Monday everyone was falling asleep',
#  'It is obvious that I am going to get a good grade on this exam',
#  'As she sang her famous line the crowd went wild']

# %%
left = paren[0].find('(')
right = paren[0].find(')')
paren[0][left:right+2]
# Out:
# '(it was so early!) '

# %%
paren[0].replace(paren[0][left:right+2],'')
# Out:
# 'When we went to town on Monday everyone was falling asleep'

# %%
new_s = 'When we went to town on Monday (e) everyone was falling asleep'

# %%
left = new_s.find('(')
right = new_s.find(')')
new_s.replace(new_s[left:right+2],'')
# Out:
# 'When we went to town on Monday everyone was falling asleep'

# %%
import pandas as pd
url1 = 'https://raw.githubusercontent.com/NYUDataBootcamp'
url2 = '/Materials/master/Data/test.csv'
url  = url1 + url2        # location of file
df = pd.read_csv(url)

# %%
url
# Out:
# 'https://raw.githubusercontent.com/NYUDataBootcamp/Materials/master/Data/test.csv'

# %%
df
# Out:
#       name  x1  x2   x3
# 0     Dave   1   2  3.5
# 1    Chase   4   3  4.3
# 2  Spencer   5   6  7.8

# %%
df = pd.read_csv(url,
#                  nrows=2,
                 usecols=[0,2])
df
# Out:
#       name  x2
# 0     Dave   2
# 1    Chase   3
# 2  Spencer   6

# %%
url = 'http://dx.doi.org/10.1787/888932937035'
pisa = pd.read_excel(url,
                     skiprows=18,             # skip the first 18 rows
                     skipfooter=7,            # skip the last 7
                     usecols=[0,1,9,13],   # select columns of interest
                     index_col=0,             # set the index as the first column
                     header=0             # set the variable names
                     )

# %%
pisa
# Out:
#                                Mathematics                   Reading    \
# NaN                   Mean score in PISA 2012  Mean score in PISA 2012
# NaN                                       NaN                      NaN
# OECD average                          494.046                  496.463
# NaN                                       NaN                      NaN
# Shanghai-China                        612.676                  569.588
# Singapore                             573.468                  542.216
# Hong Kong-China                       561.241                    544.6
# Chinese Taipei                        559.825                  523.119
# Korea                                 553.767                   535.79
# Macao-China                           538.134                  508.949
# Japan                                 536.407                  538.051
# Liechtenstein                         534.965                  515.522
# ...

# %%
pisa2 = pisa.iloc[4:,:]

# %%
pisa.columns
# Out:
# Index(['Mathematics   ', 'Reading  ', 'Science  '], dtype='object')

# %%
pisa.columns = [i.strip() for i in pisa.columns]

# %%
pisa.iloc[1:,:].dropna(subset=['Mathematics'])
# pisa.iloc[1,1]
# Out:
#                      Mathematics  Reading  Science
# OECD average             494.046  496.463   501.16
# Shanghai-China           612.676  569.588  580.118
# Singapore                573.468  542.216  551.493
# Hong Kong-China          561.241    544.6  554.937
# Chinese Taipei           559.825  523.119  523.315
# Korea                    553.767   535.79  537.788
# Macao-China              538.134  508.949  520.571
# Japan                    536.407  538.051  546.736
# Liechtenstein            534.965  515.522  524.695
# Switzerland              530.931   509.04  515.298
# Netherlands              522.972   511.23  522.056
# Estonia                  520.546  516.294  541.405
# Finland                   518.75  524.022  545.442
# Canada                   518.079  523.117  525.461
# Poland                   517.501  518.187  525.816
# Belgium                  514.745  509.108  505.457
# Germany                  513.525  507.677  524.121
# ...

# %%
import numpy as np
np.nan
# Out:
# nan

# %%
url = 'https://raw.githubusercontent.com/TheUpshot/chipotle/master/orders.tsv'
chipotle = pd.read_csv(url, sep='\t')

# %%
chipotle
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %%
# chipotle['item_price'].mean()
chipotle.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
chipotle.iloc[0,-1]
# Out:
# '$2.39 '

# %%
float(chipotle.iloc[0,-1].strip().replace('$',''))
# Out:
# 2.39

# %%
chipotle['item_price'] = chipotle['item_price'].str.strip().str.replace('$','').astype(float)

# %%
chipotle['item_price'].mean()
# Out:
# 7.464335785374397

# %%
chipotle['item_price'].sum()/chipotle['quantity'].sum()
# Out:
# 6.938889782783589

# %%
chipotle['quantity'].value_counts()
# Out:
# 1     4355
# 2      224
# 3       28
# 4       10
# 15       1
# 7        1
# 10       1
# 5        1
# 8        1
# Name: quantity, dtype: int64

# %%
chipotle['item_name'].value_counts()
# Out:
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Chips                                    211
# Steak Bowl                               211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chicken Salad Bowl                       110
# Chips and Fresh Tomato Salsa             110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %%
chipotle
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %%
chipotle['item_name']=='Chicken Bowl'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
# 5        True
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13       True
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19       True
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26       True
# 27      False
# 28      False
# 29      False
#         ...
# 4592    False
# 4593    False
# 4594    False
# 4595     True
# 4596    False
# 4597    False
# 4598    False
# 4599     True
# 4600    False
# 4601    False
# 4602    False
# 4603    False
# 4604     True
# 4605    False
# 4606    False
# 4607    False
# 4608    False
# 4609    False
# 4610    False
# 4611    False
# 4612    False
# 4613    False
# 4614    False
# 4615    False
# 4616    False
# 4617    False
# 4618    False
# 4619    False
# 4620    False
# 4621    False
# ...

# %%
chipotle.loc[chipotle['item_name']=='Chicken Bowl',:]
# Out:
#       order_id  quantity     item_name  \
# 4            2         2  Chicken Bowl
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# 42          20         1  Chicken Bowl
# 76          34         1  Chicken Bowl
# 78          34         1  Chicken Bowl
# 99          44         1  Chicken Bowl
# 110         49         1  Chicken Bowl
# 123         54         1  Chicken Bowl
# 138         62         1  Chicken Bowl
# 140         63         1  Chicken Bowl
# 142         64         1  Chicken Bowl
# 154         70         2  Chicken Bowl
# 160         73         1  Chicken Bowl
# 176         79         1  Chicken Bowl
# 182         82         1  Chicken Bowl
# 193         86         1  Chicken Bowl
# 199         89         1  Chicken Bowl
# 206         92         1  Chicken Bowl
# 209         93         1  Chicken Bowl
# 211         93         1  Chicken Bowl
# ...

# %%
chipotle.loc[chipotle['item_name']=='Chicken Bowl','item_price'].mean()
# Out:
# 10.11395316804404

# %%
(chipotle.loc[chipotle['item_name']=='Chicken Bowl','item_price'].sum()/
 chipotle.loc[chipotle['item_name']=='Chicken Bowl','quantity'].sum())
# Out:
# 9.648791064388963

# %%
chipotle['item_name'].value_counts()
# Out:
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Chips                                    211
# Steak Bowl                               211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chicken Salad Bowl                       110
# Chips and Fresh Tomato Salsa             110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %%
chipotle.loc[(chipotle['item_name']=='Chicken Bowl') | 
            (chipotle['item_name']=='Chicken Burrito'),:]
# Out:
#       order_id  quantity        item_name  \
# 4            2         2     Chicken Bowl
# 5            3         1     Chicken Bowl
# 13           7         1     Chicken Bowl
# 16           8         1  Chicken Burrito
# 17           9         1  Chicken Burrito
# 19          10         1     Chicken Bowl
# 23          12         1  Chicken Burrito
# 26          13         1     Chicken Bowl
# 29          15         1  Chicken Burrito
# 42          20         1     Chicken Bowl
# 45          21         1  Chicken Burrito
# 52          24         1  Chicken Burrito
# 63          28         1  Chicken Burrito
# 68          30         1  Chicken Burrito
# 73          33         1  Chicken Burrito
# 76          34         1     Chicken Bowl
# 78          34         1     Chicken Bowl
# 82          36         1  Chicken Burrito
# 83          37         1  Chicken Burrito
# 98          43         1  Chicken Burrito
# 99          44         1     Chicken Bowl
# ...

# %%
chipotle['item_name'].value_counts().index
# Out:
# Index(['Chicken Bowl', 'Chicken Burrito', 'Chips and Guacamole',
#        'Steak Burrito', 'Canned Soft Drink', 'Chips', 'Steak Bowl',
#        'Bottled Water', 'Chicken Soft Tacos', 'Chicken Salad Bowl',
#        'Chips and Fresh Tomato Salsa', 'Canned Soda', 'Side of Chips',
#        'Veggie Burrito', 'Barbacoa Burrito', 'Veggie Bowl', 'Carnitas Bowl',
#        'Barbacoa Bowl', 'Carnitas Burrito', 'Steak Soft Tacos',
#        '6 Pack Soft Drink', 'Chips and Tomatillo Red Chili Salsa',
#        'Chicken Crispy Tacos', 'Chips and Tomatillo Green Chili Salsa',
#        'Carnitas Soft Tacos', 'Steak Crispy Tacos',
#        'Chips and Tomatillo-Green Chili Salsa', 'Steak Salad Bowl',
#        'Nantucket Nectar', 'Barbacoa Soft Tacos',
#        'Chips and Roasted Chili Corn Salsa',
#        'Chips and Tomatillo-Red Chili Salsa', 'Izze', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa', 'Barbacoa Crispy Tacos',
# ...

# %%
chipotle['item_name'].nunique()
chipotle['item_name'].unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
# ...

# %%
chicken_list = ['Chicken Bowl','Chicken Crispy Tacos',
       'Chicken Soft Tacos', 'Chicken Burrito', 'Chicken Salad Bowl',
       'Chicken Salad']

# %%
chipotle['item_name'].isin(chicken_list)
chipotle.loc[chipotle['item_name'].isin(chicken_list),:]
# Out:
#       order_id  quantity             item_name  \
# 4            2         2          Chicken Bowl
# 5            3         1          Chicken Bowl
# 11           6         1  Chicken Crispy Tacos
# 12           6         1    Chicken Soft Tacos
# 13           7         1          Chicken Bowl
# 16           8         1       Chicken Burrito
# 17           9         1       Chicken Burrito
# 19          10         1          Chicken Bowl
# 23          12         1       Chicken Burrito
# 26          13         1          Chicken Bowl
# 29          15         1       Chicken Burrito
# 35          18         1    Chicken Soft Tacos
# 36          18         1    Chicken Soft Tacos
# 42          20         1          Chicken Bowl
# 44          20         1    Chicken Salad Bowl
# 45          21         1       Chicken Burrito
# 52          24         1       Chicken Burrito
# 63          28         1       Chicken Burrito
# 68          30         1       Chicken Burrito
# ...

# %%
chipotle['item_name'].str.contains('Chicken')
chipotle.loc[chipotle['item_name'].str.contains('Chicken'),:]
# Out:
#       order_id  quantity             item_name  \
# 4            2         2          Chicken Bowl
# 5            3         1          Chicken Bowl
# 11           6         1  Chicken Crispy Tacos
# 12           6         1    Chicken Soft Tacos
# 13           7         1          Chicken Bowl
# 16           8         1       Chicken Burrito
# 17           9         1       Chicken Burrito
# 19          10         1          Chicken Bowl
# 23          12         1       Chicken Burrito
# 26          13         1          Chicken Bowl
# 29          15         1       Chicken Burrito
# 35          18         1    Chicken Soft Tacos
# 36          18         1    Chicken Soft Tacos
# 42          20         1          Chicken Bowl
# 44          20         1    Chicken Salad Bowl
# 45          21         1       Chicken Burrito
# 52          24         1       Chicken Burrito
# 63          28         1       Chicken Burrito
# 68          30         1       Chicken Burrito
# ...

# %%
top_items = chipotle['item_name'].value_counts()[0:10].index

# %%
chipotle['item_name'].value_counts().nlargest(10)
# Out:
# Chicken Bowl           726
# Chicken Burrito        553
# Chips and Guacamole    479
# Steak Burrito          368
# Canned Soft Drink      301
# Chips                  211
# Steak Bowl             211
# Bottled Water          162
# Chicken Soft Tacos     115
# Chicken Salad Bowl     110
# Name: item_name, dtype: int64

# %%
chipotle.loc[chipotle['item_name'].isin(top_items),:]
# Out:
#       order_id  quantity            item_name  \
# 4            2         2         Chicken Bowl
# 5            3         1         Chicken Bowl
# 7            4         1        Steak Burrito
# 9            5         1        Steak Burrito
# 10           5         1  Chips and Guacamole
# 12           6         1   Chicken Soft Tacos
# 13           7         1         Chicken Bowl
# 14           7         1  Chips and Guacamole
# 16           8         1      Chicken Burrito
# 17           9         1      Chicken Burrito
# 19          10         1         Chicken Bowl
# 20          10         1  Chips and Guacamole
# 23          12         1      Chicken Burrito
# 26          13         1         Chicken Bowl
# 29          15         1      Chicken Burrito
# 31          16         1        Steak Burrito
# 34          17         1        Bottled Water
# 35          18         1   Chicken Soft Tacos
# 36          18         1   Chicken Soft Tacos
# ...

# %%
chipotle['choice_description'].str.contains('Salsa').fillna(False)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
# 5        True
# 6       False
# 7        True
# 8        True
# 9        True
# 10      False
# 11       True
# 12       True
# 13       True
# 14      False
# 15      False
# 16       True
# 17       True
# 18      False
# 19       True
# 20      False
# 21       True
# 22      False
# 23       True
# 24      False
# 25      False
# 26       True
# 27       True
# 28      False
# 29       True
#         ...
# 4592     True
# 4593     True
# 4594     True
# 4595     True
# 4596    False
# 4597    False
# 4598    False
# 4599     True
# 4600    False
# 4601    False
# 4602     True
# 4603     True
# 4604     True
# 4605    False
# 4606    False
# 4607     True
# 4608     True
# 4609    False
# 4610     True
# 4611     True
# 4612     True
# 4613    False
# 4614    False
# 4615     True
# 4616    False
# 4617     True
# 4618     True
# 4619     True
# 4620     True
# 4621     True
# ...

# %%
d = chipotle.loc[chipotle['item_name'].str.contains('Burrito'),'quantity'].sum()
n = chipotle.loc[(chipotle['item_name'].str.contains('Burrito'))&
                 (chipotle['choice_description'].str.contains('Salsa').fillna(False)),'quantity'].sum()
n/d
# Out:
# 0.9683184402924452

# %%
d
# Out:
# 1231

# %%
chipotle.loc[chipotle['item_name'].str.contains('Burrito'),'choice_description'].value_counts()
# Out:
# [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice, Cheese, Sour Cream]]                                                                                                         24
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]                                                                                            18
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream]]                                                                                                                18
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]                                                                                                       18
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Lettuce]]                                                                                                                   15
# ...
