# %% [markdown]
# #### Problem 1

# %%
import pandas as pd
url = 'C:/NYU/Data_Bootcamp/Assignment 4/master_data_ready.csv'
df = pd.read_csv(url , na_values = ['\\N'])

# %%
df
# Out:
#                                   job_id                vertical  \
# 0       20198581751789701529910950958638  Information Technology
# 1        8895868916034283132954081837418  Information Technology
# 2        1519847330480116680516242585467  Information Technology
# 3       92511853348028679647877877985294  Information Technology
# 4         490138684948094100363899533762  Information Technology
# 5       74657902746882254946742123272434  Information Technology
# 6       67959912699822604603156520211049  Information Technology
# 7       62960553541696238196645947323426  Information Technology
# 8       90717759116185198593932094841046  Information Technology
# 9       16387272974132263790431897281915  Information Technology
# 10      72696625716373834009704285573063  Information Technology
# 11       7574193811517788303631671726249  Information Technology
# 12       9522301324327623359690770686252  Information Technology
# ...

# %%
df.columns = [i.capitalize() for i in df.columns]

# %%
df
# Out:
#                                   Job_id                Vertical  \
# 0       20198581751789701529910950958638  Information Technology
# 1        8895868916034283132954081837418  Information Technology
# 2        1519847330480116680516242585467  Information Technology
# 3       92511853348028679647877877985294  Information Technology
# 4         490138684948094100363899533762  Information Technology
# 5       74657902746882254946742123272434  Information Technology
# 6       67959912699822604603156520211049  Information Technology
# 7       62960553541696238196645947323426  Information Technology
# 8       90717759116185198593932094841046  Information Technology
# 9       16387272974132263790431897281915  Information Technology
# 10      72696625716373834009704285573063  Information Technology
# 11       7574193811517788303631671726249  Information Technology
# 12       9522301324327623359690770686252  Information Technology
# ...

# %% [markdown]
# #### Problem 2

# %%
df.isnull().sum()
# Out:
# Job_id               0
# Vertical             0
# Company         110408
# Post_date            0
# Fill_date       151118
# Time_to_fill    151118
# Salary               0
# Location        110730
# City            112673
# State           110823
# Zip             114932
# County          114610
# Region_state    115592
# Latitude        113595
# Longitude       113595
# dtype: int64

# %% [markdown]
# #### Problem 3

# %%
Master_Clean = df.drop(['Latitude','Longitude'],axis=1)

# %%
Master_Clean
# Out:
#                                   Job_id                Vertical  \
# 0       20198581751789701529910950958638  Information Technology
# 1        8895868916034283132954081837418  Information Technology
# 2        1519847330480116680516242585467  Information Technology
# 3       92511853348028679647877877985294  Information Technology
# 4         490138684948094100363899533762  Information Technology
# 5       74657902746882254946742123272434  Information Technology
# 6       67959912699822604603156520211049  Information Technology
# 7       62960553541696238196645947323426  Information Technology
# 8       90717759116185198593932094841046  Information Technology
# 9       16387272974132263790431897281915  Information Technology
# 10      72696625716373834009704285573063  Information Technology
# 11       7574193811517788303631671726249  Information Technology
# 12       9522301324327623359690770686252  Information Technology
# ...

# %% [markdown]
# #### Problem 4

# %%
Master_Clean.loc[(Master_Clean['State']=='NY') &
            (Master_Clean['Post_date'].str.contains('2018')),:]
# Out:
#                                   Job_id                Vertical  \
# 43      49166544275228979011485468005581  Information Technology
# 56      32216824414038021036854127631301  Information Technology
# 122     17686258734635581425901950904423  Information Technology
# 284     68180000463505362721268597011820  Information Technology
# 324     75506920553773445036596485697789  Information Technology
# 363       467895701373045028283543226368  Information Technology
# 401     50485279672009898454911121142589  Information Technology
# 419     51333496372464413223171949419278  Information Technology
# 430     18396944660472507504542277085363  Information Technology
# 600     98550477161084188489066376128064  Information Technology
# 622      5300000483730778286537489207643  Information Technology
# 629     94516996256928574491330047487931  Information Technology
# 643     48476158435811127247708931642112  Information Technology
# ...

# %% [markdown]
# #### Problem 5

# %%
Master_Clean.loc[(~ Master_Clean['State'].isin(['NY','CA'])) & (Master_Clean['Salary'] > 80000),:].dropna(subset=['State'])
# or use the below code
#Master_Clean.loc[(~ Master_Clean['State'].isin(['NY','CA'])) & (Master_Clean['Salary'] > 80000) & (Master_Clean['State'].notnull()),:]
# Out:
#                                   Job_id                Vertical  \
# 4         490138684948094100363899533762  Information Technology
# 5       74657902746882254946742123272434  Information Technology
# 14      84400929153273312343387471187380  Information Technology
# 23      73008818513451263769918234460534  Information Technology
# 27      18130503948134891967593913939232  Information Technology
# 31      92708943921819158278275137368013  Information Technology
# 40       9661280239453334742826718781338  Information Technology
# 42        406721259826597271166136103276  Information Technology
# 53       7955450235772249401977199367187  Information Technology
# 61      45230337933216733091735774621770  Information Technology
# 70      32300234787209199670389747356731  Information Technology
# 79        681377002829632837068544453736  Information Technology
# 91       2294022611392523687558580960170  Information Technology
# ...

# %% [markdown]
# #### Problem 6

# %%
#Assigning Master clean contents to another df to keep Master Clean as is
Time_to_fill_df = df.drop(['Latitude','Longitude'],axis=1)
Time_to_fill_df['Time_to_fill'].isnull().sum()
# Out:
# 151118

# %%
Time_to_fill_df['Time_to_fill'].fillna(Time_to_fill_df['Time_to_fill'].median() , inplace= True)

# %%
Time_to_fill_df.iloc[0:25,:]
# Out:
#                               Job_id                Vertical  \
# 0   20198581751789701529910950958638  Information Technology
# 1    8895868916034283132954081837418  Information Technology
# 2    1519847330480116680516242585467  Information Technology
# 3   92511853348028679647877877985294  Information Technology
# 4     490138684948094100363899533762  Information Technology
# 5   74657902746882254946742123272434  Information Technology
# 6   67959912699822604603156520211049  Information Technology
# 7   62960553541696238196645947323426  Information Technology
# 8   90717759116185198593932094841046  Information Technology
# 9   16387272974132263790431897281915  Information Technology
# 10  72696625716373834009704285573063  Information Technology
# 11   7574193811517788303631671726249  Information Technology
# 12   9522301324327623359690770686252  Information Technology
# 13  52640544511439669779820035559105  Information Technology
# ...

# %%
Time_to_fill_df.iloc[-25:,:]
# Out:
#                                   Job_id                Vertical  \
# 199975  48041536241494217662250110664243  Information Technology
# 199976  23453717852758575601814024263130  Information Technology
# 199977   5326123493516782780021258450715  Information Technology
# 199978  68852945689125823800407883282647  Information Technology
# 199979    240100362157077358238131440676  Information Technology
# 199980  46456241379591785042717238258330  Information Technology
# 199981   4001013685275695634806875913258  Information Technology
# 199982  60522090748706799278712939323611  Information Technology
# 199983  18256672733125291179263139025573  Information Technology
# 199984    597499738167314929115828559698  Information Technology
# 199985  15451008755759513152673330905817  Information Technology
# 199986   5994888770269885528828055360439  Information Technology
# 199987  10937360886054861021535485260314  Information Technology
# ...

# %% [markdown]
# #### Problem 7

# %%
Master_Clean.loc[(Master_Clean['State']=='NJ'), :].loc[: ,['Company', 'Post_date' , 'Salary' ]].dropna(subset=['Company', 'Post_date' , 'Salary'])
# Out:
#                                                  Company   Post_date  Salary
# 248                                           Siemens AG  2018-03-21  117154
# 347                                        Stefanini Inc  2017-01-25  104023
# 425              On The Border Mexican Grill and Cantina  2017-08-02   17115
# 474                                                Ricoh  2018-03-15   39479
# 545                                           BNY Mellon  2016-10-28  104219
# 634                                       NFI Industries  2018-04-14   81348
# 724                                    Quest Diagnostics  2017-08-29   36549
# 833                                    Bed Bath & Beyond  2018-01-18  123018
# 916                                       APN Consulting  2018-07-17  109966
# 965                      Stewart's All American | Walker  2017-08-18   35169
# 974                           Partner's Consulting, Inc.  2017-01-19   86999
# ...

# %% [markdown]
# #### Problem 8

# %%
Master_Clean.loc[Master_Clean['State'].isin(['NC','PA', 'TX']),:].loc[:,['Company', 'Post_date' , 'Time_to_fill', 'Salary' ]].dropna(subset=['Company', 'Post_date' , 'Time_to_fill' , 'Salary'])
# Out:
#                                                Company   Post_date  \
# 4                                             Mindteck  2018-02-20
# 91                 Texas A&M University Corpus Christi  2016-10-14
# 172                                 Camber Corporation  2016-10-07
# 208                           WellSpan Health Services  2016-12-04
# 337                                           Mckesson  2016-12-20
# 362                                             PACCAR  2017-01-19
# 407                          Global Process Automation  2016-10-21
# 421                                     ECRI Institute  2016-11-22
# 548                                 Hope for the Heart  2016-10-18
# 674                                         Smartronix  2016-09-02
# 692                                      KellyMitchell  2016-12-03
# 823                                         BNY Mellon  2016-09-02
# 855                                    L3 Technologies  2018-06-19
# ...

# %% [markdown]
# #### Problem 9

# %%
Master_Clean.loc[(Master_Clean['Region_state'].str.contains('New York', na=False, regex=False)) |
                (Master_Clean['Region_state'].str.contains('Los Angeles-Long', na=False, regex=False)),:].loc[:,['City','State','County','Region_state']]
# Out:
#                          City State       County  \
# 1                  Northridge    CA  Los Angeles
# 47              New York City    NY     New York
# 56              New York City    NY     New York
# 71                   Melville    NY      Suffolk
# 122             New York City    NY     New York
# 137                    Irvine    CA       Orange
# 222                  Pasadena    CA  Los Angeles
# 268               Studio City    CA  Los Angeles
# 284                   Bohemia    NY      Suffolk
# 315             New York City    NY     New York
# 324             New York City    NY     New York
# 334                  Valencia    CA  Los Angeles
# 347               Jersey City    NJ       Hudson
# 349                Sun Valley    CA  Los Angeles
# 350             New York City    NY     New York
# 363             New York City    NY     New York
# 394             New York City    NY     New York
# 401                  Flushing    NY       Queens
# ...

# %% [markdown]
# #### Problem 10

# %%
Master_Clean.loc[(Master_Clean['Post_date'].str.contains('2018')) | 
                 (Master_Clean['Post_date'].str.contains('2017')),:].loc[(Master_Clean['Region_state'].str.contains('New York')) |
                 (Master_Clean['Region_state'].str.contains('Seattle')),:].loc[(Master_Clean['Salary'] > 80000),:].loc[:,['Company', 'Vertical' , 'Post_date' , 'Salary' ]].dropna(subset=['Company'])
# Out:
#                                         Company                Vertical  \
# 47                                          AIG  Information Technology
# 56                                         MUFG  Information Technology
# 61                                    Microsoft  Information Technology
# 122                                         RBC  Information Technology
# 280     General Dynamics Information Technology  Information Technology
# 324            Federal Reserve Bank of New York  Information Technology
# 347                               Stefanini Inc  Information Technology
# 363                                 Wells Fargo  Information Technology
# 374                                    T-Mobile  Information Technology
# 394                                         RBC  Information Technology
# 430                             JP Morgan Chase  Information Technology
# 456                                    T-Mobile  Information Technology
# ...

# %% [markdown]
# #### Problem 11

# %%
n = Master_Clean.loc[(Master_Clean['Salary'] >= 100000) & (Master_Clean['State']=='NY') & (Master_Clean['Post_date'].str.contains('2018')),'Job_id'].count()
n
# Out:
# 1021

# %%
d = Master_Clean.loc[(Master_Clean['State']=='NY') & (Master_Clean['Post_date'].str.contains('2018')),'Job_id'].count()
d
# Out:
# 2739

# %%
percentage = ( n / d ) * 100
percentage
# Out:
# 37.27637824023366

# %% [markdown]
# #### Problem 12

# %%
NY_Mean = Master_Clean.loc[(Master_Clean['State']=='NY') , 'Salary' ].mean()
NY_Mean
# Out:
# 84802.44652701213

# %%
CA_Mean = Master_Clean.loc[(Master_Clean['State']=='CA') , 'Salary' ].mean()
CA_Mean
# Out:
# 82992.58246408188

# %%
n = Master_Clean.loc[(Master_Clean['State'].isin(['NY','CA'])) &
                     (Master_Clean['Company'].str.strip()=='Wells Fargo')].loc[(Master_Clean['Salary'] > NY_Mean) |
                                                            (Master_Clean['Salary'] > CA_Mean),'Job_id'].count()
n
# Out:
# 66

# %%
#denominator - all Wells Fargo jobs in NY or CA
d = Master_Clean.loc[(Master_Clean['State'].isin(['NY','CA'])) 
                     & (Master_Clean['Company'].str.strip()=='Wells Fargo'),'Job_id'].count()
d
# Out:
# 82

# %%
percentage = (n/d) * 100
percentage
# Out:
# 80.48780487804879
